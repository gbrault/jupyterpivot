# %%
from jupyterpivot import HelloWorld

# %%
help(HelloWorld)
# Out:
# Help on class HelloWorld in module jupyterpivot.example:
#
# class HelloWorld(ipywidgets.widgets.domwidget.DOMWidget)
#  |  HelloWorld(*args, **kwargs)
#  |
#  |  An example widget.
#  |
#  |  Method resolution order:
#  |      HelloWorld
#  |      ipywidgets.widgets.domwidget.DOMWidget
#  |      ipywidgets.widgets.widget.Widget
#  |      ipywidgets.widgets.widget.LoggingHasTraits
#  |      traitlets.traitlets.HasTraits
#  |      traitlets.traitlets.HasDescriptors
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Public constructor
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  pivot_options
#  |      An instance of a Python dict.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ipywidgets.widgets.domwidget.DOMWidget:
#  |
#  |  add_class(self, className)
# ...

# %%
! start sandman2ctl -l "mysql+mysqldb://jupyter:jupyter@mariadb.vps_jupyter/jupyter?charset=utf8"

# %%
! curl -s "http://localhost:5000/"
# Out:
# {"AB":"/ab{/index}","ART":"/art{/index}","AUF":"/auf{/index}","AUF4":"/auf4{/index}","BEK":"/bek{/index}","BEP":"/bep{/index}","FB_POS":"/fb_pos{/index}","FERT_F10":"/fert_f10{/index}","FSR":"/fsr{/index}","KUN_KUN":"/kun_kun{/index}","KUN_LIE":"/kun_lie{/index}","LJOUR":"/ljour{/index}","OPS_01":"/ops_01{/index}","RAP":"/rap{/index}","TAB_LAND":"/tab_land{/index}","TAB_VTR":"/tab_vtr{/index}","UFIA":"/ufia{/index}","classification":"/classification{/index}","productcost1":"/productcost1{/index}","productcost1classified":"/productcost1classified{/index}","productcosting":"/productcosting{/index}","productcosting1":"/productcosting1{/index}","sales_all":"/sales_all{/index}","salescosting":"/salescosting{/index}","tabledictionnary":"/tabledictionnary{/index}","worldmap_latlng":"/worldmap_latlng{/id}"}

# %%
! curl -s "http://localhost:5000/sales_all/?Invoice%20Date=YEAR,2020&collection&split=Invoice%20Date,%Y-%m-%d&limit=5"
# Out:
# [{"Activity":"Trading","Article Name":"Credit note","Article Num":"000","Batch Num":0,"CLASSIFICATION":"Credit note","Category Invoice":"G","City":"Krefeld","Client Name":"ALBERDINGK BOLEY GmbH","Client Num":"110517","Costs of Goods Sold":null,"Country":"DEUTSCHLAND","Invoice Date":"2020-01-06","Invoice Date_day":6,"Invoice Date_month":1,"Invoice Date_year":2020,"Invoice Num":100532,"KG/LTR/STK":"STK","Order Num":313948,"Packaging":"000","Product line":"Administration ","Quantity":0,"Salesmanager":"David Zilm","Turnover":-5210.0,"Unit Cost":null,"Unit Price":5210.0,"Volume":0.0,"index":16635},{"Activity":"Trading","Article Name":"parmetol DF 35 N","Article Num":"RSM016","Batch Num":50238002,"CLASSIFICATION":"Formulation TB RSM","Category Invoice":"G","City":"Kaohsiung","Client Name":"WWRC Taiwan Co., Ltd.","Client Num":"110861","Costs of Goods Sold":-1040.0,"Country":"TAIWAN","Invoice Date":"2020-01-07","Invoice Date_day":7,"Invoice Date_month":1,"Invoice Date_year":2020,"Invoice Num
# ...

# %%
test={}

# %%
test = pivot.pivot_options

# %%
test = {'derivedAttributes': {},
 'hiddenAttributes': [],
 'hiddenFromAggregators': [],
 'hiddenFromDragDrop': [],
 'menuLimit': 500,
 'cols': ['Invoice Date_month'],
 'rows': ['CLASSIFICATION'],
 'vals': ['Turnover'],
 'rowOrder': 'key_a_to_z',
 'colOrder': 'key_a_to_z',
 'exclusions': {},
 'inclusions': {},
 'unusedAttrsVertical': 85,
 'autoSortUnusedAttrs': False,
 'showUI': True,
 'sorters': {},
 'inclusionsInfo': {},
 'aggregatorName': 'Sum',
 'rendererName': 'Table'}

# %%
test = {'derivedAttributes': {},
 'hiddenAttributes': [],
 'hiddenFromAggregators': [],
 'hiddenFromDragDrop': [],
 'menuLimit': 500,
 'cols': ['Invoice Date_month'],
 'rows': ['Salesmanager', 'Invoice Num', 'Category Invoice', 'Client Name'],
 'vals': ['Turnover'],
 'rowOrder': 'value_z_to_a',
 'colOrder': 'key_a_to_z',
 'exclusions': {'Salesmanager': ['Additiv Chemie Luers',
   'Daniel Siebert',
   'David Zilm',
   'Fernando Scandoleira',
   'Guus Abercrombie',
   'Jamie Vink',
   'Mark Nicholls',
   'Paul Heere',
   'Paul Maalouf',
   'Phil Blundell',
   'Salvatore Aita',
   'Stefan Marchand',
   'Tan Phu Huynh',
   'Tobias Rheinländer',
   'Vijay Nair']},
 'inclusions': {'Salesmanager': ['null']},
 'unusedAttrsVertical': 85,
 'autoSortUnusedAttrs': False,
 'showUI': True,
 'sorters': {},
 'inclusionsInfo': {'Salesmanager': ['null']},
 'aggregatorName': 'Sum',
 'rendererName': 'Heatmap'}

# %%
pivot = HelloWorld(url="/proxy/5000/sales_all/?Invoice%20Date=YEAR,2020&split=Invoice%20Date,%Y-%m-%d&collection", pivot_options=test)

# %%
pivot
# Out:
# HelloWorld(pivot_options={'derivedAttributes': {}, 'hiddenAttributes': [], 'hiddenFromAggregators': [], 'hidde…
